# %% [markdown]
# <h1><center>Farrukh's Week 3 - Assignment Part 2</center></h1>

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

## Visulaziations
from geopy.geocoders import Nominatim
import folium
import time

## KMeans
from sklearn.cluster import KMeans

from matplotlib import pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline
print("Loaded all required Librarires!!!")
# Out:
# Loaded all required Librarires!!!

# %% [markdown]
# #### Load the Pandas DataFrame We Stored Earlier

# %%
toronto_data = pd.read_csv('toronto_data.scv', index_col=1)

# %% [markdown]
# #### Load the Latituted, Longitude from the GeoSpatial_Coordinates File

# %%
# Due to huge number of calls loading geo points from the file
geo = pd.read_csv('Geospatial_Coordinates.csv')
geo = geo.rename(columns={'Postal Code': 'PostalCode'})

# %%
toronto_data = toronto_data.merge(geo, on='PostalCode', how='left')
toronto_data.head(10)
# Out:
#   PostalCode  Unnamed: 0                                   Neighborhood  \
# 0        M1B           1                                  Rouge,Malvern
# 1        M1C           2           Highland Creek,Rouge Hill,Port Union
# 2        M1E           3                Guildwood,Morningside,West Hill
# 3        M1G           4                                         Woburn
# 4        M1H           5                                      Cedarbrae
# 5        M1J           6                            Scarborough Village
# 6        M1K           7      East Birchmount Park,Ionview,Kennedy Park
# 7        M1L           8                  Clairlea,Golden Mile,Oakridge
# 8        M1M           9  Cliffcrest,Cliffside,Scarborough Village West
# 9        M1N          10                     Birch Cliff,Cliffside West
#
#        Borough  Latitude_x  Longitude_x  Latitude_y  Longitude_y   Latitude  \
# 0  Scarborough   43.806686   -79.194353   43.806686   -79.194353  43.806686
# ...

# %%
toronto_data
# Out:
#     PostalCode  Unnamed: 0                                       Neighborhood  \
# 0          M1B           1                                      Rouge,Malvern
# 1          M1C           2               Highland Creek,Rouge Hill,Port Union
# 2          M1E           3                    Guildwood,Morningside,West Hill
# 3          M1G           4                                             Woburn
# 4          M1H           5                                          Cedarbrae
# 5          M1J           6                                Scarborough Village
# 6          M1K           7          East Birchmount Park,Ionview,Kennedy Park
# 7          M1L           8                      Clairlea,Golden Mile,Oakridge
# 8          M1M           9      Cliffcrest,Cliffside,Scarborough Village West
# 9          M1N          10                         Birch Cliff,Cliffside West
# 10         M1P          11  Dorset Park,Scarborough Town Centre,Wexford He...
# ...

# %% [markdown]
# ### Presist the Data Frame to File

# %%
toronto_data.to_csv('toronto_data.csv')

# %%
toronto_data.shape
# Out:
# (103, 10)
